# %%
# !pip install --upgrade flwr tensorflow

import flwr as fl
import tensorflow as tf
from google.colab import drive
import numpy as np
import os
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, BatchNormalization, LeakyReLU
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
# Out:
# Collecting flwr
#   Downloading flwr-1.25.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Collecting click<8.2.0 (from flwr)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting cryptography<45.0.0,>=44.0.1 (from flwr)
#   Downloading cryptography-44.0.3-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: grpcio<2.0.0,>=1.70.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (1.76.0)
# Collecting grpcio-health-checking<2.0.0,>=1.70.0 (from flwr)
#   Downloading grpcio_health_checking-1.76.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting iterators<0.0.3,>=0.0.2 (from flwr)
#   Downloading iterators-0.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (2.0.2)
# Collecting pathspec<0.13.0,>=0.12.1 (from flwr)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: protobuf<7.0.0,>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (5.29.5)
# Collecting pycryptodome<4.0.0,>=3.18.0 (from flwr)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from flwr) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (2.32.4)
# Requirement already satisfied: rich<14.0.0,>=13.5.0 in /usr/local/lib/python3.12/dist-packages (from flwr) (13.9.4)
# Collecting tomli<3.0.0,>=2.0.1 (from flwr)
#   Downloading tomli-2.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Collecting tomli-w<2.0.0,>=1.0.0 (from flwr)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: typer<0.21.0,>=0.12.5 in /usr/local/lib/python3.12/dist-packages (from flwr) (0.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<45.0.0,>=44.0.1->flwr) (2.0.0)
# Collecting protobuf<7.0.0,>=5.28.0 (from flwr)
#   Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->flwr) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0.0,>=13.5.0->flwr) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0.0,>=13.5.0->flwr) (2.19.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.21.0,>=0.12.5->flwr) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<45.0.0,>=44.0.1->flwr) (2.23)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.5.0->flwr) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Downloading flwr-1.25.0-py3-none-any.whl (727 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.1/727.1 kB 17.8 MB/s eta 0:00:00
# Downloading tensorflow-2.20.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (620.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 620.7/620.7 MB 1.2 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.9 MB/s eta 0:00:00
# Downloading cryptography-44.0.3-cp39-abi3-manylinux_2_34_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 105.9 MB/s eta 0:00:00
# Downloading grpcio_health_checking-1.76.0-py3-none-any.whl (18 kB)
# Downloading iterators-0.0.2-py3-none-any.whl (3.9 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.3/323.3 kB 25.4 MB/s eta 0:00:00
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 56.7 MB/s eta 0:00:00
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 96.5 MB/s eta 0:00:00
# Downloading tomli-2.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.1/250.1 kB 19.3 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Installing collected packages: tomli-w, tomli, pycryptodome, protobuf, pathspec, iterators, click, tensorboard, grpcio-health-checking, cryptography, tensorflow, flwr
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.19.0
#     Uninstalling tensorboard-2.19.0:
#       Successfully uninstalled tensorboard-2.19.0
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.19.0
#     Uninstalling tensorflow-2.19.0:
#       Successfully uninstalled tensorflow-2.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.20.0 which is incompatible.
# pyopenssl 24.2.1 requires cryptography<44,>=41.0.5, but you have cryptography 44.0.3 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.20.0 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.20.0 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.33.2 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.2 which is incompatible.
# Successfully installed click-8.1.8 cryptography-44.0.3 flwr-1.25.0 grpcio-health-checking-1.76.0 iterators-0.0.2 pathspec-0.12.1 protobuf-6.33.2 pycryptodome-3.23.0 tensorboard-2.20.0 tensorflow-2.20.0 tomli-2.3.0 tomli-w-1.2.0

# %%
CLIENT_ID = 1

drive.mount('/content/drive', force_remount=True)
DRIVE_DATA_PATH = '***' #enter path to data folder
data_path = os.path.join(DRIVE_DATA_PATH, f'client_{CLIENT_ID}_data.npz')

print(f"--- This notebook is now CLIENT #{CLIENT_ID} ---")
with np.load(data_path) as data:
    x_train = data['x'].astype(np.float32)
print(f"Successfully loaded {len(x_train)} samples for this client.")
# Out:
# Mounted at /content/drive
# --- This notebook is now CLIENT #1 ---
# Successfully loaded 20000 samples for this client.

# %%
LATENT_DIM = 100
IMG_SHAPE = (28, 28, 1)

def build_generator():
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense, LeakyReLU, BatchNormalization, Reshape
    model = Sequential([
        Dense(256, input_dim=LATENT_DIM), LeakyReLU(alpha=0.2), BatchNormalization(momentum=0.8),
        Dense(512), LeakyReLU(alpha=0.2), BatchNormalization(momentum=0.8),
        Dense(1024), LeakyReLU(alpha=0.2), BatchNormalization(momentum=0.8),
        Dense(np.prod(IMG_SHAPE), activation='tanh'), Reshape(IMG_SHAPE)
    ], name="generator")
    return model

def build_discriminator():
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Flatten, Dense, LeakyReLU
    model = Sequential([
        Flatten(input_shape=IMG_SHAPE), Dense(512), LeakyReLU(alpha=0.2),
        Dense(256), LeakyReLU(alpha=0.2), Dense(1, activation='sigmoid')
    ], name="discriminator")
    return model

class GanClient(fl.client.NumPyClient):
    def __init__(self, x_train):
        if x_train.max() > 1.0: self.x_train = (x_train - 127.5) / 1.5
        else: self.x_train = x_train * 2.0 - 1.0
        if self.x_train.ndim == 3: self.x_train = np.expand_dims(self.x_train, axis=3)

        self.generator = build_generator()
        self.discriminator = build_discriminator()
        self.generator_optimizer = tf.keras.optimizers.Adam(0.0002, 0.5)
        self.discriminator_optimizer = tf.keras.optimizers.Adam(0.0002, 0.5)
        self.loss_fn = tf.keras.losses.BinaryCrossentropy()

    def get_parameters(self, config):
        return self.generator.get_weights()

    @tf.function
    def _train_step(self, real_images):
        batch_size = tf.shape(real_images)[0]
        noise = tf.random.normal([batch_size, LATENT_DIM])

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            generated_images = self.generator(noise, training=True)

            real_output = self.discriminator(real_images, training=True)
            fake_output = self.discriminator(generated_images, training=True)

            gen_loss = self.loss_fn(tf.ones_like(fake_output), fake_output)

            real_loss = self.loss_fn(tf.ones_like(real_output), real_output)
            fake_loss = self.loss_fn(tf.zeros_like(fake_output), fake_output)
            disc_loss = real_loss + fake_loss

        grads_gen = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        grads_disc = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)

        self.generator_optimizer.apply_gradients(zip(grads_gen, self.generator.trainable_variables))
        self.discriminator_optimizer.apply_gradients(zip(grads_disc, self.discriminator.trainable_variables))

    def fit(self, parameters, config):
        self.generator.set_weights(parameters)

        dataset = tf.data.Dataset.from_tensor_slices(self.x_train).shuffle(len(self.x_train)).batch(32)

        for image_batch in dataset:
            self._train_step(image_batch)

        return self.generator.get_weights(), len(self.x_train), {}

    def evaluate(self, parameters, config):
        return 0.0, len(self.x_train), {}

# %%
print(f"\n--- Starting Client #{CLIENT_ID} ---")
client = GanClient(x_train)

fl.client.start_numpy_client(
    server_address="***",  #enter server ip
    client=client
)
print(f"\n--- Client #{CLIENT_ID} has finished. ---")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# WARNING :   DEPRECATED FEATURE: flwr.client.start_numpy_client() is deprecated.
# 	Instead, use `flwr.client.start_client()` by ensuring you first call the `.to_client()` method as shown below:
# 	flwr.client.start_client(
# 		server_address='<IP>:<PORT>',
# 		client=FlowerClient().to_client(), # <-- where FlowerClient is of type flwr.client.NumPyClient object
# 	)
# 	Using `start_numpy_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.client.start_numpy_client() is deprecated.
# 	Instead, use `flwr.client.start_client()` by ensuring you first call the `.to_client()` method as shown below:
# 	flwr.client.start_client(
# 		server_address='<IP>:<PORT>',
# 		client=FlowerClient().to_client(), # <-- where FlowerClient is of type flwr.client.NumPyClient object
# 	)
# 	Using `start_numpy_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING :   DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.client.start_client() is deprecated.
# 	Instead, use the `flower-supernode` CLI command to start a SuperNode as shown below:
#
# 		$ flower-supernode --insecure --superlink='<IP>:<PORT>'
#
# 	To view all available options, run:
#
# 		$ flower-supernode --help
#
# 	Using `start_client()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# DEBUG:flwr:Using InMemoryObjectStore
# DEBUG:flwr:Opened insecure gRPC connection (no certificates were passed)
# DEBUG:flwr:ChannelConnectivity.IDLE
# DEBUG:flwr:ChannelConnectivity.CONNECTING
# --- Starting Client #1 ---
# DEBUG:flwr:ChannelConnectivity.READY
# INFO :
# INFO:flwr:
# INFO :      Received: train message de1b0114-7fff-4b69-9d40-243991b4387e
# INFO:flwr:Received: train message de1b0114-7fff-4b69-9d40-243991b4387e
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 0ceeedb3-78bd-4c9e-8bed-2c44ea1933b5
# INFO:flwr:Received: evaluate message 0ceeedb3-78bd-4c9e-8bed-2c44ea1933b5
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message b5087789-c362-4df9-ae6a-fd92eebc0c8a
# INFO:flwr:Received: train message b5087789-c362-4df9-ae6a-fd92eebc0c8a
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 61c13ab9-504c-45cf-a1c0-994d99e3379e
# INFO:flwr:Received: evaluate message 61c13ab9-504c-45cf-a1c0-994d99e3379e
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 97a27792-e462-4e72-a8e4-a5cae490dcbb
# INFO:flwr:Received: train message 97a27792-e462-4e72-a8e4-a5cae490dcbb
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 232bd501-dd4c-48a5-ba27-3d3b07d102e0
# INFO:flwr:Received: evaluate message 232bd501-dd4c-48a5-ba27-3d3b07d102e0
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 240eab18-31bb-4f9f-a824-1360c259f9c1
# INFO:flwr:Received: train message 240eab18-31bb-4f9f-a824-1360c259f9c1
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 269337c1-bf7c-465e-92ad-fd86bfea4ad8
# INFO:flwr:Received: evaluate message 269337c1-bf7c-465e-92ad-fd86bfea4ad8
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message cf737473-c13a-4652-86b0-1ab0fb1e2d7d
# INFO:flwr:Received: evaluate message cf737473-c13a-4652-86b0-1ab0fb1e2d7d
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 5cf9c202-0942-450e-9859-ced2ab462cd8
# INFO:flwr:Received: train message 5cf9c202-0942-450e-9859-ced2ab462cd8
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message ca3b8acb-7f24-43ce-b81d-fabe50dcc953
# INFO:flwr:Received: evaluate message ca3b8acb-7f24-43ce-b81d-fabe50dcc953
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 35e64d53-d13c-46d2-8008-3a6f0ae8ca4d
# INFO:flwr:Received: train message 35e64d53-d13c-46d2-8008-3a6f0ae8ca4d
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 2218d502-790b-4560-9a30-eeefbe5dcf54
# INFO:flwr:Received: evaluate message 2218d502-790b-4560-9a30-eeefbe5dcf54
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message d57090d6-6dfc-46e7-b984-95bcb6321112
# INFO:flwr:Received: train message d57090d6-6dfc-46e7-b984-95bcb6321112
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message d8fee331-2a78-4a08-8fa9-be197f4f59ad
# INFO:flwr:Received: evaluate message d8fee331-2a78-4a08-8fa9-be197f4f59ad
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message e3d23f40-f8c3-4b11-a4d9-11145794698d
# INFO:flwr:Received: train message e3d23f40-f8c3-4b11-a4d9-11145794698d
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 5d1f9afb-59af-4152-a966-1ddad2d36d73
# INFO:flwr:Received: evaluate message 5d1f9afb-59af-4152-a966-1ddad2d36d73
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 61667a54-d15f-4f78-adc8-74b9d9ec2531
# INFO:flwr:Received: train message 61667a54-d15f-4f78-adc8-74b9d9ec2531
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 4208c2cb-8735-42c1-a585-24fe84c4eb26
# INFO:flwr:Received: evaluate message 4208c2cb-8735-42c1-a585-24fe84c4eb26
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message cf118d5d-fd5e-48b3-9c24-d1619d0baff4
# INFO:flwr:Received: train message cf118d5d-fd5e-48b3-9c24-d1619d0baff4
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 2368cbd8-3f5e-4264-b1b8-a20e2abb8bf8
# INFO:flwr:Received: evaluate message 2368cbd8-3f5e-4264-b1b8-a20e2abb8bf8
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 811057cf-acd8-4ff2-8de7-1bef0609790c
# INFO:flwr:Received: train message 811057cf-acd8-4ff2-8de7-1bef0609790c
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 0cacc1f7-8bf1-44ef-a217-9147becc3bf1
# INFO:flwr:Received: evaluate message 0cacc1f7-8bf1-44ef-a217-9147becc3bf1
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 9b2ee48d-0e6f-44d0-b9fc-e50c39713551
# INFO:flwr:Received: train message 9b2ee48d-0e6f-44d0-b9fc-e50c39713551
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message ba3af598-3665-4a7c-9c39-69e403caa097
# INFO:flwr:Received: evaluate message ba3af598-3665-4a7c-9c39-69e403caa097
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 87174034-d14b-48ca-af92-aa33411dca9a
# INFO:flwr:Received: train message 87174034-d14b-48ca-af92-aa33411dca9a
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 716eaf16-d83d-4257-b384-9f3e884bff17
# INFO:flwr:Received: evaluate message 716eaf16-d83d-4257-b384-9f3e884bff17
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message ca928d9b-7071-4ab9-a30a-84743ccdcc51
# INFO:flwr:Received: train message ca928d9b-7071-4ab9-a30a-84743ccdcc51
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 4f35a5b3-80b9-452b-b9d7-4ab5fa62f51a
# INFO:flwr:Received: evaluate message 4f35a5b3-80b9-452b-b9d7-4ab5fa62f51a
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 84434acb-88c6-43e4-816a-69df7f5b9522
# INFO:flwr:Received: train message 84434acb-88c6-43e4-816a-69df7f5b9522
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 69548d4e-ce23-45b3-bfe9-45c71fbc0901
# INFO:flwr:Received: evaluate message 69548d4e-ce23-45b3-bfe9-45c71fbc0901
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 818ccb8c-7f6b-4839-907d-0ea94086c4c8
# INFO:flwr:Received: train message 818ccb8c-7f6b-4839-907d-0ea94086c4c8
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message eb4f4ddf-9ffc-4811-be8f-e365af4668d3
# INFO:flwr:Received: evaluate message eb4f4ddf-9ffc-4811-be8f-e365af4668d3
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message bc28c2c8-4b3b-494c-acf2-df09219f174e
# INFO:flwr:Received: train message bc28c2c8-4b3b-494c-acf2-df09219f174e
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 5a7ae5f1-dc7e-4da7-ac0c-ea542369b024
# INFO:flwr:Received: evaluate message 5a7ae5f1-dc7e-4da7-ac0c-ea542369b024
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 924a81a7-acf3-44cf-9c3d-02223d794c37
# INFO:flwr:Received: train message 924a81a7-acf3-44cf-9c3d-02223d794c37
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message b079cbc9-e0c8-4d19-8763-7c3d2d45adee
# INFO:flwr:Received: evaluate message b079cbc9-e0c8-4d19-8763-7c3d2d45adee
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message d1eb3fce-fc8c-4f67-bb9d-c783224c0ce3
# INFO:flwr:Received: train message d1eb3fce-fc8c-4f67-bb9d-c783224c0ce3
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 47a9ae64-8ab7-49d4-bc83-c1e8964df9e2
# INFO:flwr:Received: evaluate message 47a9ae64-8ab7-49d4-bc83-c1e8964df9e2
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message c366090a-f28c-45fa-a771-e1cda006b70d
# INFO:flwr:Received: train message c366090a-f28c-45fa-a771-e1cda006b70d
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message c0aecdf7-a04c-48d6-8006-31b348858cfc
# INFO:flwr:Received: evaluate message c0aecdf7-a04c-48d6-8006-31b348858cfc
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message ac6f38c7-8717-4125-a3fc-edfe43a7384c
# INFO:flwr:Received: train message ac6f38c7-8717-4125-a3fc-edfe43a7384c
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 35e532b3-a9df-4e46-9e61-4693ca182185
# INFO:flwr:Received: evaluate message 35e532b3-a9df-4e46-9e61-4693ca182185
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message f3d1c1d3-e8f7-4c95-bd02-e59eb9cfe220
# INFO:flwr:Received: train message f3d1c1d3-e8f7-4c95-bd02-e59eb9cfe220
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 96bbbed4-c16b-43f0-aed9-14ce84ae9669
# INFO:flwr:Received: evaluate message 96bbbed4-c16b-43f0-aed9-14ce84ae9669
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: train message 2c957af0-8f72-44df-ab60-dd25af68f8e8
# INFO:flwr:Received: train message 2c957af0-8f72-44df-ab60-dd25af68f8e8
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: evaluate message 4d31c928-44a5-46e9-b5a5-e0e08ac0ef82
# INFO:flwr:Received: evaluate message 4d31c928-44a5-46e9-b5a5-e0e08ac0ef82
# INFO :      Sent reply
# INFO:flwr:Sent reply
# INFO :
# INFO:flwr:
# INFO :      Received: reconnect message c7828b2b-dae7-4e24-a6b2-ffb89e9d28fe
# INFO:flwr:Received: reconnect message c7828b2b-dae7-4e24-a6b2-ffb89e9d28fe
# DEBUG:flwr:gRPC channel closed
# INFO :      Disconnect and shut down
# INFO:flwr:Disconnect and shut down
# --- Client #1 has finished. ---
